# %%
import pandas as pd

# %% [markdown]
# # Create a dataframe, dataframe is a 2D array.

# %% [markdown]
# # Create a dataframe from dictionary

# %%
df_dict = pd.DataFrame({'Name': ['Deep','Pari','Anchal'], 'Marks': [76,67,78]})

# %%
df_dict
# Out:
#      Name  Marks
# 0    Deep     76
# 1    Pari     67
# 2  Anchal     78

# %% [markdown]
# # load csv data using pandas' read_csv method

# %%
df = pd.read_csv('StockData.csv')

# %% [markdown]
# # head() method returns the first 5 rows of the dataframe by default,otherwise mention the number of rows

# %%
df.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %%
df.head(7) # mention he number of rows in head() method
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556
# 5  AAPL  15-02-2013  65.7371
# 6  AAPL  19-02-2013  65.7128

# %% [markdown]
# # tail() method is used to get last rows of the dataframe, by default is 5 otherwise mention

# %%
df.tail()
# Out:
#      stock        date  price
# 5031   ZTS  01-02-2018  77.82
# 5032   ZTS  02-02-2018  76.78
# 5033   ZTS  05-02-2018  73.83
# 5034   ZTS  06-02-2018  73.27
# 5035   ZTS  07-02-2018  73.86

# %% [markdown]
# # shape, shape attribute is used to get the shape of dataframe, rows and columns

# %%
df.shape
# Out:
# (5036, 3)

# %% [markdown]
# # Describe method gives the numeric information like, count,std,min,max,mean,25%,50%,75%

# %%
df.describe()
# Out:
#              price
# count  5036.000000
# mean     73.057030
# std      29.011126
# min      28.400000
# 25%      54.067500
# 50%      69.085000
# 75%      79.250000
# max     179.260000

# %% [markdown]
# # Calculate mean, median, min, max

# %%
df.min()
# Out:
# stock          AAPL
# date     01-02-2016
# price          28.4
# dtype: object

# %%
df.max()
# Out:
# stock           ZTS
# date     31-12-2015
# price        179.26
# dtype: object

# %%
df['price'].mean() #takes numeric data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: '...'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.mean() #takes numeric data
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/nanops.
# 5031   ZTS  01-02-2018
# 5032   ZTS  02-02-2018
# 5033   ZTS  05-02-2018
# 5034   ZTS  06-02-2018
# 5035   ZTS  07-02-2018
#
# [5036 rows x 2 columns]

# %% [markdown]
# # Dropping columns, axis = 0, means drop function is for rows

# %%
df.drop([1,2,3], axis=0)
# Out:
#      stock        date    price
# 0     AAPL  08-02-2013  67.8542
# 4     AAPL  14-02-2013  66.6556
# 5     AAPL  15-02-2013  65.7371
# 6     AAPL  19-02-2013  65.7128
# 7     AAPL  20-02-2013  64.1214
# ...    ...         ...      ...
# 5031   ZTS  01-02-2018  77.8200
# 5032   ZTS  02-02-2018  76.7800
# 5033   ZTS  05-02-2018  73.8300
# 5034   ZTS  06-02-2018  73.2700
# 5035   ZTS  07-02-2018  73.8600
#
# [5033 rows x 3 columns]

# %%
df.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %% [markdown]
# # apply() method is used for applying user defined function for each element of the column

# %%
def half(x):
    return x*0.5

# %%
x = df['price'].apply(half)

# %%
x
# Out:
# 0       33.9271
# 1       34.2807
# 2       33.4214
# 3       33.3578
# 4       33.3278
#          ...
# 5031    38.9100
# 5032    38.3900
# 5033    36.9150
# 5034    36.6350
# 5035    36.9300
# Name: price, Length: 5036, dtype: float64

# %% [markdown]
# # value_counts(), is used for counting the occurrence of the each value in column

# %%
df.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %%
df['stock'].value_counts()
# Out:
# stock
# AAPL    1259
# SNI     1259
# TJX     1259
# ZTS     1259
# Name: count, dtype: int64

# %% [markdown]
# # sort_values() is used to sort values by column name

# %%
df.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %%
df.sort_values(by = 'price')
# Out:
#      stock        date   price
# 4072   ZTS  11-04-2014   28.40
# 4073   ZTS  14-04-2014   28.48
# 4075   ZTS  16-04-2014   28.53
# 4074   ZTS  15-04-2014   28.55
# 4076   ZTS  17-04-2014   28.60
# ...    ...         ...     ...
# 1247  AAPL  23-01-2018  177.04
# 1241  AAPL  12-01-2018  177.09
# 1245  AAPL  19-01-2018  178.46
# 1243  AAPL  17-01-2018  179.10
# 1244  AAPL  18-01-2018  179.26
#
# [5036 rows x 3 columns]
